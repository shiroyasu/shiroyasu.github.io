# %% [markdown]
# <a href="https://shiroyasu.github.io/index.html">home</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/index.html">Teaching</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/nit.html">NIT</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/2019s/dic3-ca.html">2019 Differential and Integral Calculus III</a> &#155;&#155;

# %% [markdown]
# # 微分積分学III <span style="color: #808080; ">Differential and Integral Calculus III</span> #
#
# ## 定期試験の結果 ##
#
# ### <a href="https://shiroyasu.github.io/teaching/2019s/dic3-mdt.pdf">中間試験</a>（<a href="https://shiroyasu.github.io/teaching/2019s/dic3-mdt-ans.pdf">解答</a>） ###

# %%
mdt <- c(6,22,24,26,30,33,36,39,39,40,40);

# %% [markdown]
# #### 受験者数（履修者数 12名） ####

# %%
length(mdt)
# Out:
# [1] 11

# %% [markdown]
# #### 平均値（満点は40点） ####

# %%
round(mean(mdt),digits=2)
# Out:
# [1] 30.45

# %% [markdown]
# #### 中間値 ####

# %%
median(mdt)
# Out:
# [1] 33

# %% [markdown]
# #### 標準偏差 ####

# %%
round(sd(mdt),digits=2)
# Out:
# [1] 10.47

# %% [markdown]
# #### 得点分布 ####

# %%
hist(mdt, main="2019年度春「微分積分学III」中間試験", xlab="点数", breaks=seq(0,40,4), ylim=c(0,5), col="#53A9F5", border = "#0F6AC0")
# Out:
# Plot with title “2019年度春「微分積分学III」中間試験”

# %% [markdown]
# ### <a href="https://shiroyasu.github.io/teaching/2019s/dic3-edt.pdf">期末試験</a>（<a href="https://shiroyasu.github.io/teaching/2019s/dic3-edt-ans.pdf">解答</a>） ###

# %%
edt <- c(36,34,26,22,20,18,18,16,12,8);

# %% [markdown]
# #### 受験者数（履修者数 12名） ####

# %%
length(edt)
# Out:
# [1] 10

# %% [markdown]
# #### 平均値（満点は40点） ####

# %%
round(mean(edt),digits=2)
# Out:
# [1] 21

# %% [markdown]
# #### 中間値 ####

# %%
median(edt)
# Out:
# [1] 19

# %% [markdown]
# #### 標準偏差 ####

# %%
round(sd(edt),digits=2)
# Out:
# [1] 8.91

# %% [markdown]
# #### 得点分布 ####

# %%
hist(edt, main="2019年度春「微分積分学III」期末試験", xlab="点数", breaks=seq(0,40,4), ylim=c(0,5), col="#53A9F5", border = "#0F6AC0")
# Out:
# Plot with title “2019年度春「微分積分学III」期末試験”

# %% [markdown]
# ## 総合 ##

# %% [markdown]
# <table>
#     <tr><td>AA</td><td>A</td><td>B</td><td>C</td><td>D</td><td>/</td></tr>
#     <tr><td>1</td><td>2</td><td>3</td><td>0</td><td>4</td><td>2</td></tr>
# </table>

# %% [markdown]
# #### 合格率（合格者/履修者） ####

# %%
round(100*(1+2+3+0)/12,digits=1)
# Out:
# [1] 50

# %% [markdown]
# #### 合格率（合格者/受験者） ####

# %%
round(100*(1+2+3+0)/10,digits=1)
# Out:
# [1] 60
