# %% [markdown]
# <a href="https://shiroyasu.github.io/index.html">home</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/index.html">Teaching</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/nit.html">NIT</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/2019s/de-c.html">2019 Differential Equations</a> &#155;&#155;

# %% [markdown]
# # 微分方程式 <span style="color: #808080; ">Differential Equations</span> #
#
# ## 定期試験の結果 ##

# %% [markdown]
# ### <a href="https://shiroyasu.github.io/teaching/2019s/de-mdt.pdf">中間試験</a>（<a href="https://shiroyasu.github.io/teaching/2019s/de-mdt-ans.pdf">解答</a>） ###

# %%
mdt <- c(5,9,12,17,29,29,30,31,31,33,33,34,34,34,37,38,39)

# %% [markdown]
# #### 受験者数（履修者数 27名） ####

# %%
length(mdt)
# Out:
# [1] 17

# %% [markdown]
# #### 平均値（満点は40点） ####

# %%
round(mean(mdt),digits=2)
# Out:
# [1] 27.94

# %% [markdown]
# #### 中間値 ####

# %%
median(mdt)
# Out:
# [1] 31

# %% [markdown]
# #### 標準偏差 ####

# %%
round(sd(mdt),digits=2)
# Out:
# [1] 10.46

# %% [markdown]
# #### 得点分布 ####

# %%
hist(mdt, main="2019年度春「微分方程式」中間試験", xlab="点数", breaks=seq(0,40,4), ylim=c(0,6), col="#53A9F5", border = "#0F6AC0")
# Out:
# Plot with title “2019年度春「微分方程式」中間試験”

# %% [markdown]
# ### <a href="https://shiroyasu.github.io/teaching/2019s/de-edt.pdf">期末試験</a>（<a href="https://shiroyasu.github.io/teaching/2019s/de-edt-ans.pdf">解答</a>） ###

# %%
edt <- c(12,12,14,16,22,26,26,32,32,32,32,32,32,40,40,40)

# %% [markdown]
# #### 受験者数（履修者数 27名） ####

# %%
length(edt)
# Out:
# [1] 16

# %% [markdown]
# #### 平均値（満点は40点） ####

# %%
round(mean(edt),digits=2)
# Out:
# [1] 27.5

# %% [markdown]
# #### 中間値 ####

# %%
median(edt)
# Out:
# [1] 32

# %% [markdown]
# #### 標準偏差 ####

# %%
round(sd(edt),digits=2)
# Out:
# [1] 9.73

# %% [markdown]
# #### 得点分布 ####

# %%
hist(edt, main="2019年度春「微分方程式」期末試験", xlab="点数", breaks=seq(0,40,4), ylim=c(0,6), col="#53A9F5", border = "#0F6AC0")
# Out:
# Plot with title “2019年度春「微分方程式」期末試験”

# %% [markdown]
# ## 総合 ##

# %% [markdown]
# <table>
#     <tr><td>AA</td><td>A</td><td>B</td><td>C</td><td>D</td><td>/</td></tr>
#     <tr><td>3</td><td>3</td><td>4</td><td>4</td><td>2</td><td>11</td></tr>
# </table>

# %% [markdown]
# #### 合格率（合格者/履修者) ####

# %%
round(100*(3+3+4+4)/27,digits=1)
# Out:
# [1] 51.9

# %% [markdown]
# #### 合格率（合格者/受験者） ####

# %%
round(100*(3+3+4+4)/16,digits=1)
# Out:
# [1] 87.5
